# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1><b>DATA SCIENCE COURSE</b></h1>

# %% [markdown]
# <p style = "color:gray"><b>MOST POPULAR DATA SCIENCE CODE LANGUAGES ARE AS LISTED BELOW;</b></p>
# <ul  style = "color:#990099">
# <li>PYHTON,</li>
# <li>R,</li>
# <li>SQL,</li>
# <li>JAVA,</li>
# <li>JULIA,</li>
# <li>C/C++,</li>
# <li>JAVASCRIPT,</li>
# <li>SWIFT,</li>
# <li>GO,</li>
# <li>MATLAB,</li>
# <li>SAS</li>
# </ul>

# %% [markdown]
# <div>
# <p style ="color:gray"><b>SOME OF THE MOST POPULAR PYHTON LIBRARIRES USED IN DATA SCIENCE</b></P>
# <ul>
# <li style ="color:#990099" ><b style ="color:black">NumPy</b> :Fundamental package for scientific computing with support for large, multi-dimensional arrays and matrices, along with mathematical functions.</li>
# <li style ="color:#990099" ><b style ="color:black">Pandas</b> :Powerful library for data manipulation and analysis, providing data structures like DataFrames that are essential for working with structured data.</li>
# <li style ="color:#990099" ><b style ="color:black">Matplotlib</b> :Comprehensive library for creating static, animated, and interactive visualizations in Python.</li>
# <li style ="color:#990099" ><b style ="color:black">Seaborn</b> :Statistical data visualization library based on Matplotlib, providing a high-level interface for drawing attractive and informative statistical graphics.</li>
# <li style ="color:#990099" ><b style ="color:black">Scikit-learn</b> :Machine learning library that provides simple and efficient tools for data analysis and modeling, including various machine learning algorithms.</li>
# <li style ="color:#990099" ><b style ="color:black">TensorFlow</b> :An open-source machine learning framework developed by Google for building and training deep learning models.</li>
# <li style ="color:#990099" ><b style ="color:black">PyTorch</b> :A deep learning framework that provides dynamic computational graphs, making it particularly popular in research and for applications like natural language processing and computer vision.</li>
# </ul>
# </div>

# %% [markdown]
# <div>
# <p style ="color:gray"><b>TOOLS OF DATA SCIENCE</b></p>
# <ul>
# <li style ="color:#990099" ><b style ="color:black">Jupyter Notebooks</b> : An interactive computing environment that allows users to create and share documents containing live code, equations, visualizations, and narrative text.</li>
# <li style ="color:#990099" ><b style ="color:black">Anaconda</b> :Anaconda is a distribution of the Python programming language along with a collection of open-source packages and tools.</li>
# <li style ="color:#990099" ><b style ="color:black">R Studio</b> : RStudio is an integrated development environment (IDE) designed specifically for the R programming language. R Language is one of the most common languages in Data Science.</li>
# <li style ="color:#990099" ><b style ="color:black">Git/Github</b> : Git is a distributed version control system that tracks changes in code repositories, and GitHub is a web-based platform that provides hosting, collaboration, and additional features for Git repositories.</li>

# %% [markdown]
# <p style = "color:gray"><b>EXAMPLES OF ARITHMETIC EXPRESSIONS</b></p>
# <ul>
# <li style ="color:#990099" >in Pyhton <b style ="color:black">"print (5+2)"</b> code will output addition of numbers stated in parenthesis.</li>
# <li style ="color:#990099" >in Pyhton <b style ="color:black">"print (126/6)"</b> code will output division of numbers stated in parenthesis.</li>
# </ul>

# %%
# simple code snippets for addition and multiplication
print (478*619)
print (558+157)
print ((558+157)+(478*619))

# %%
# Here is function to convert minutes to hours
minutes = 240
hours = minutes/60
print (hours)

# %% [markdown]
# <p style = "color:gray"><b>NOTEBOOK OBJECTIVES</b></p>
# <ul style = "color:black font-family:Calibri">
# <li>Data Science Programming Languages</li>
# <li>Tools for Data Science</li>
# <li>Code Examples in Pyhton</li>
# </ul>

# %% [markdown]
# <h2>AUTHOR</h2>
# <p> ISMAIL UGUZ </p>
